# %% [markdown]
# <a href="https://colab.research.google.com/github/okuokuch/pokemon_home/blob/main/poke_home_competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pokemon HOMEのシーズン情報取得
# ## 公式大会の情報取得

# %% [markdown]
# Githubからファイルを取得

# %%
# !git clone https://github.com/okuokuch/pokemon_home.git
# Out:
# Cloning into 'pokemon_home'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 39 (delta 16), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
import json
import pandas as pd
import ast
df_poke = pd.read_csv("./pokemon_home/poke_id.csv", encoding="UTF-8")
with open("./pokemon_home/item.json","r",encoding="UTF-8") as f:
  data = f.read()
  item_json = ast.literal_eval(data)
with open("./pokemon_home/move.json","r",encoding="UTF-8") as f:
  data = f.read()
  move_json = ast.literal_eval(data)
with open("./pokemon_home/seikaku.json","r",encoding="UTF-8") as f:
  data = f.read()
  seikaku_json = ast.literal_eval(data)
with open("./pokemon_home/tokusei.json","r",encoding="UTF-8") as f:
  data = f.read()
  tokusei_json = ast.literal_eval(data)

# %%
import requests

#データ取得のためのダミー設定値。スマホからアクセスしているような設定。
headers = {
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'countrycode': '304',
    'authorization': 'Bearer',
    'langcode': '1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 8.0; Pixel 2 Build/OPD3.170816.012) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Mobile Safari/537.36',
    'content-type': 'application/json'
}

data = '{"soft":"Sw"}'
#リクエストを出してシーズン情報を取得
response_base = requests.post('https://api.battle.pokemon-home.com/cbd/competition/internet/list', headers=headers, data=data)
info_all = json.loads(response_base.text)

# %%
#大会タイトルとサブタイトルの表示
info_competitions = info_all['list']['list']
list_competiton =[]
list_name =[]
list_subname = []
for info_competition in info_competitions:
  list_competiton.append(info_competition)
  list_name.append(info_competitions[str(info_competition)]['name'])
  list_subname.append(info_competitions[str(info_competition)]['subname'])
df_comp_name = pd.DataFrame([list_competiton, list_name, list_subname]).T
df_comp_name.columns = ['大会ID','タイトル','サブタイトル']
df_comp_name
# Out:
#       大会ID                                   タイトル    サブタイトル
# 0   100061              ポケモンジャパンチャンピオンシップス2022 予選  マスターカテゴリ
# 1   100060              ポケモンジャパンチャンピオンシップス2022 予選  ジュニアカテゴリ
# 2   100059     2022 International Challenge April  マスターカテゴリ
# 3   100058     2022 International Challenge April  ジュニアカテゴリ
# 4   100057     2022 International Challenge March  マスターカテゴリ
# 5   100056     2022 International Challenge March  ジュニアカテゴリ
# 6   100055  2022 International Challenge February  マスターカテゴリ
# 7   100054  2022 International Challenge February  ジュニアカテゴリ
# 8   100053                             新春！おみくじバトル  マスターカテゴリ
# 9   100052                             新春！おみくじバトル  ジュニアカテゴリ
# 10  100051                                プリティプリマ  マスターカテゴリ
# 11  100050                                プリティプリマ  ジュニアカテゴリ
# 12  100048                                ジムチャレンジ  ジュニアカテゴリ
# 13  100049                                ジムチャレンジ  マスターカテゴリ
# 14  100046                               トリックリリック  ジュニアカテゴリ
# 15  100047                               トリックリリック  マスターカテゴリ
# 16  100044                          レジェンド オブ ラウンド  ジュニアカテゴリ
# 17  100045                          レジェンド オブ ラウンド  マスターカテゴリ
# 18  100042                              セイムダブルビート  ジュニアカテゴリ
# 19  100043                              セイムダブルビート  マスターカテゴリ
# 20  100041                             ウォーターパラダイス  マスターカテゴリ
# 21  100040                             ウォーターパラダイス  ジュニアカテゴリ
# 22  100038                                 セイムビート  ジュニアカテゴリ
# 23  100039                                 セイムビート  マスターカテゴリ
# 24  100034              ポケモンジャパンチャンピオンシップス2021 予選  マスターカテゴリ
# 25  100033              ポケモンジャパンチャンピオンシップス2021 予選  ジュニアカテゴリ
# 26  100031                              スパイクチャレンジ  ジュニアカテゴリ
# 27  100032                              スパイクチャレンジ  マスターカテゴリ
# 28  100029    Global Challenge 2021 Second Winter  ジュニアカテゴリ
# 29  100030    Global Challenge 2021 Second Winter  マスターカテゴリ
# 30  100028           Global Challenge 2021 Winter  マスターカテゴリ
# 31  100027           Global Challenge 2021 Winter  ジュニアカテゴリ
# 32  100025                         ポケモン竜王戦2020 予選  ジュニアカテゴリ
# 33  100026                         ポケモン竜王戦2020 予選  マスターカテゴリ
# 34  100024                              カンムリビギニング  マスターカテゴリ
# 35  100023                              カンムリビギニング  ジュニアカテゴリ
# 36  100022                               バトルレジェンド  マスターカテゴリ
# 37  100021                               バトルレジェンド  ジュニアカテゴリ
# 38  100019           Global Challenge 2020 Autumn  ジュニアカテゴリ
# 39  100020           Global Challenge 2020 Autumn  マスターカテゴリ
# 40  100015                               ヨロイビギニング  マスターカテゴリ
# 41  100014                               ヨロイビギニング  ジュニアカテゴリ
# 42  100013                      ポケモン日本一決定戦2020 予選  マスターカテゴリ
# 43  100012                      ポケモン日本一決定戦2020 予選  ジュニアカテゴリ
# 44  100011       2020 International Challenge May  マスターカテゴリ
# 45  100010       2020 International Challenge May  ジュニアカテゴリ
# 46  100009     2020 International Challenge April  マスターカテゴリ
# 47  100008     2020 International Challenge April  ジュニアカテゴリ
# 48  100007                         しんそく！シングルバトル！！  マスターカテゴリ
# 49  100006                         しんそく！シングルバトル！！  ジュニアカテゴリ
# 50  100005      2020 International Challenge Feb.  マスターカテゴリ
# 51  100004      2020 International Challenge Feb.  ジュニアカテゴリ
# 52  100003                              ガラル☆ルーキーズ  ジュニアカテゴリ
# 53  100002                              ガラル☆ルーキーズ  マスターカテゴリ
# 54  100001                               ガラルビギニング

# %% [markdown]
# # 取得したい大会情報の設定
# competitonに大会IDを記入してください。

# %%
#@title 取り出したい情報 { display-mode: "both" }
#competitonには取得したい大会IDを上の表から見つけ出して記入してください。
competition = "100059" #@param {type:"string"}

# %%
#指定したシーズン情報を取り出すためのリクエストパラメータ取得
info_competiton = info_competitions[competition]

params = {'id':competition, 'rst':str(info_competiton['rst']), 'ts1':str(info_competiton['ts1']), 'ts2':str(info_competiton['ts2'])}

# %%
pokemon_json ={}
for x in range(1,6):
    adress = "https://resource.pokemon-home.com/battledata/ranking/"+params["id"]+"/"+params["rst"]+"/"+params["ts2"]+"/pdetail-"+str(x)
    headers = {
        'user-agent': 'Mozilla/5.0 (Linux; Android 8.0; Pixel 2 Build/OPD3.170816.012) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Mobile Safari/537.36',
        'content-type': 'application/json',
    }

    response = requests.get(adress, headers=headers)
    json_read= json.loads(response.text)
    pokemon_json.update(json_read)

# %%
#ポケモン使用率ランキングを取得
adress = "https://resource.pokemon-home.com/battledata/ranking/"+params["id"]+"/"+params["rst"]+"/"+params["ts2"]+"/pokemon"
headers = {
    'user-agent': 'Mozilla/5.0 (Linux; Android 8.0; Pixel 2 Build/OPD3.170816.012) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Mobile Safari/537.36',
    'content-type': 'application/json',
}

response = requests.get(adress, headers=headers)
ranking_pokemon_json= json.loads(response.text)

# %%
#ポケモン仕様ランキングのdf作成
df_poke_rank = pd.DataFrame()
list_poke_rank=[]
for i, poke in enumerate(ranking_pokemon_json):
  id = poke['id']
  form = poke['form']
  name = df_poke[(df_poke['id'] == id) & (df_poke['リージョン'] == form)]['ポケモン名'].values[0]
  list_poke_rank.append([i+1, name])
df_poke_rank = df_poke_rank.append(list_poke_rank)
df_poke_rank.columns = ['順位','ポケモン名']

# %%
from tqdm import tqdm
df_poke_item = pd.DataFrame()
df_poke_nature = pd.DataFrame()
df_poke_ability = pd.DataFrame()
df_poke_move = pd.DataFrame()


for poke in tqdm(pokemon_json):
  for region in pokemon_json[str(poke)]:
    #ポケモン名を取得
    name = df_poke[(df_poke['id'] == int(poke)) & (df_poke['リージョン'] == int(region))]['ポケモン名'].values[0]
    temoti = pokemon_json[str(poke)][region]['temoti']

    list_motimono = [name]
    list_seikaku = [name]
    list_tokusei = [name]
    list_waza = [name]

    #もちもので展開しlistに格納。
    for info_motimono in temoti['motimono']:
      motimono = item_json[int(info_motimono['id'])]
      list_motimono.append(motimono)
      list_motimono.append(info_motimono['val'])    
    #性格で展開しlistに格納。
    for info_seikaku in temoti['seikaku']:
      seikaku = seikaku_json[int(info_seikaku['id'])]
      list_seikaku.append(seikaku)
      list_seikaku.append(info_seikaku['val'])
    #特性で展開しlistに格納。
    for info_tokusei in temoti['tokusei']:
      tokusei = tokusei_json[int(info_tokusei['id'])]
      list_tokusei.append(seikaku)
      list_tokusei.append(info_tokusei['val'])
    #技名で展開しlistに格納。
    for info_waza in temoti['waza']:
      waza = move_json[int(info_waza['id'])]
      list_waza.append(waza)
      list_waza.append(info_waza['val'])
    df_poke_item = df_poke_item.append([list_motimono])
    df_poke_nature = df_poke_nature.append([list_seikaku])
    df_poke_ability = df_poke_ability.append([list_tokusei])
    df_poke_move = df_poke_move.append([list_waza])
# Out:
# 100%|██████████| 650/650 [00:09<00:00, 69.31it/s]

# %%
#各データフレームはポケモン名、要素1、割合1、要素2、割合2、、、となるのでそれに沿ってカラム名付与
column_item = ['ポケモン名']
column_nature = ['ポケモン名']
column_ability = ['ポケモン名']
column_move = ['ポケモン名']

column_item += ['アイテム', '割合']*int((len(df_poke_item.columns)-1)/2)
column_nature += ['アイテム', '割合']*int((len(df_poke_nature.columns)-1)/2)
column_ability += ['アイテム', '割合']*int((len(df_poke_ability.columns)-1)/2)
column_move += ['アイテム', '割合']*int((len(df_poke_move.columns)-1)/2)

df_poke_item.columns = column_item
df_poke_nature.columns = column_nature
df_poke_ability.columns = column_ability
df_poke_move.columns = column_move

# %% [markdown]
# # Google Driveにcsvファイルを書き出し。
# Google Driveをマウントして、そこにcsvファイルを書き出しする。

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#必要に応じて"./drive/MyDrive/poke_home_item.csv"の部分を変更してください。この設定だと、おそらく接続したGoogle Driveのトップページに保存されます。
#もしdataというフォルダの中に保存したい場合は、"./drive/MyDrive/data/poke_home_item.csv"とすればよいはずです。
df_poke_item.to_csv("./drive/MyDrive/poke_home_item.csv",encoding="shift-jis", index = False)
df_poke_nature.to_csv("./drive/MyDrive/poke_home_nature.csv",encoding="shift-jis", index = False)
df_poke_ability.to_csv("./drive/MyDrive/poke_home_ability.csv",encoding="shift-jis", index = False)
df_poke_move.to_csv("./drive/MyDrive/poke_home_move.csv",encoding="shift-jis", index = False)
df_poke_rank.to_csv("./drive/MyDrive/poke_home_rank.csv",encoding="shift-jis", index = False)
